# %%
import neo4j
import json
import time
import pandas as pd

# %%
# !ls
# Out:
# 'Project Code.ipynb'	    Untitled.ipynb	       facebook_features.json
# 'Project Code_copy.ipynb'   facebook_edges.csv	       facebook_target.csv
#  README.md		    facebook_edges_small.csv

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))
session = driver.session(database="neo4j")

# %%
def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    query = "MATCH (node)-[relationship]->() DELETE node, relationship"
    session.run(query)
    query = "MATCH (node) DELETE node"
    session.run(query)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    result = session.run(query, **kwargs)
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    return df

# %%
def my_neo4j_nodes_relationships():
    "print all the nodes and relationships"
    print("-------------------------")
    print("  Nodes:")
    print("-------------------------")
    query = """
        MATCH (n) 
        RETURN n.name AS node_name, labels(n) AS labels, n.id AS node_id
        ORDER BY n.name
    """
    df_nodes = my_neo4j_run_query_pandas(query)
    print(df_nodes)

    print("-------------------------")
    print("  Relationships:")
    print("-------------------------")
    query = """
        MATCH (n1)-[r]->(n2) 
        RETURN n1.id AS node_id_1, labels(n1) AS node_1_labels,
               type(r) AS relationship_type,
               n2.id AS node_id_2, labels(n2) AS node_2_labels
        ORDER BY node_id_1, node_id_2
    """
    df_rels = my_neo4j_run_query_pandas(query)
    print(df_rels)
    print("-------------------------")

# %%
# 1. Wipe out any existing data
my_neo4j_wipe_out_database()

# 2. Read CSVs into Pandas
edges_df   = pd.read_csv("facebook_edges.csv")   # columns: id_1, id_2
#edges_df = edges_df[:100]

targets_df = pd.read_csv("facebook_target.csv")  # columns: id, facebook_id, page_name, page_type
#targets_df = targets_df[:100]
# 3. Optionally read the JSON features (if present)
try:
    with open("facebook_features.json", "r") as f:
        features_data = json.load(f)  # dict: { "nodeID": [featureIndices,...], ... }
except FileNotFoundError:
    features_data = {}
    print("No facebook_features.json found; skipping feature import.")

# %%
for i, row in targets_df.iterrows():
    node_id       = row["id"]
    facebook_id   = row["facebook_id"]
    page_name     = row["page_name"]
    page_type     = row["page_type"]
    
    node_id_str   = str(node_id)
    node_features = features_data.get(node_id_str, [])  # list or empty

    query = """
    CREATE (p:Page {
        id: $node_id,
        facebook_id: $facebook_id,
        page_name: $page_name,
        page_type: $page_type,
        features: $features
    })
    """
    session.run(query, {
        "node_id"    : node_id,
        "facebook_id": facebook_id,
        "page_name"  : page_name,
        "page_type"  : page_type,
        "features"   : node_features
    })

    # (Option A) Print every 1000 nodes
    if i % 1000 == 0 and i != 0:
        print(f"  Created {i} nodes so far...")
print("Done")

# %%
start_time = time.time()
last_print_time = start_time

for i, row in edges_df.iterrows():
    source_id = row["id_1"]
    target_id = row["id_2"]
    
    query = """
    MATCH (a:Page {id: $source_id})
    MATCH (b:Page {id: $target_id})
    CREATE (a)-[:LIKES]->(b)
    """
    session.run(query, {"source_id": source_id, "target_id": target_id})

    # (Option B) Print every 5 seconds
    current_time = time.time()
    if current_time - last_print_time > 5:  # e.g. 5s
        elapsed = current_time - start_time
        print(f"  Processed {i} edges in {elapsed:.1f} seconds so far...")
        last_print_time = current_time
print("Done")
# Out:
#   Processed 261 edges in 5.0 seconds so far...
#   Processed 523 edges in 10.0 seconds so far...
#   Processed 784 edges in 15.0 seconds so far...
#   Processed 1046 edges in 20.0 seconds so far...
#   Processed 1310 edges in 25.0 seconds so far...
#   Processed 1575 edges in 30.0 seconds so far...
#   Processed 1835 edges in 35.1 seconds so far...
#   Processed 2093 edges in 40.1 seconds so far...
#   Processed 2351 edges in 45.1 seconds so far...
#   Processed 2607 edges in 50.1 seconds so far...
#   Processed 2864 edges in 55.1 seconds so far...
#   Processed 3120 edges in 60.1 seconds so far...
#   Processed 3379 edges in 65.1 seconds so far...
#   Processed 3637 edges in 70.1 seconds so far...
#   Processed 3894 edges in 75.1 seconds so far...
#   Processed 4153 edges in 80.1 seconds so far...
#   Processed 4413 edges in 85.1 seconds so far...
#   Processed 4671 edges in 90.1 seconds so far...
#   Processed 4928 edges in 95.2 seconds so far...
#   Processed 5184 edges in 100.2 seconds so far...
#   Processed 5440 edges in 105.2 seconds so far...
#   Processed 5697 edges in 110.2 seconds so far...
#   Processed 5955 edges in 115.2 seconds so far...
#   Processed 6212 edges in 120.2 seconds so far...
#   Processed 6468 edges in 125.2 seconds so far...
#   Processed 6726 edges in 130.2 seconds so far...
#   Processed 6983 edges in 135.2 seconds so far...
#   Processed 7239 edges in 140.2 seconds so far...
#   Processed 7497 edges in 145.2 seconds so far...
#   Processed 7752 edges in 150.3 seconds so far...
#   Processed 8007 edges in 155.3 seconds so far...
#   Processed 8263 edges in 160.3 seconds so far...
#   Processed 8521 edges in 165.3 seconds so far...
#   Processed 8779 edges in 170.3 seconds so far...
#   Processed 9036 edges in 175.3 seconds so far...
#   Processed 9293 edges in 180.3 seconds so far...
#   Processed 9550 edges in 185.3 seconds so far...
#   Processed 9806 edges in 190.3 seconds so far...
#   Processed 10063 edges in 195.3 seconds so far...
#   Processed 10320 edges in 200.4 seconds so far...
#   Processed 10576 edges in 205.4 seconds so far...
#   Processed 10833 edges in 210.4 seconds so far...
#   Processed 11090 edges in 215.4 seconds so far...
#   Processed 11348 edges in 220.4 seconds so far...
#   Processed 11605 edges in 225.4 seconds so far...
#   Processed 11863 edges in 230.4 seconds so far...
#   Processed 12120 edges in 235.4 seconds so far...
#   Processed 12377 edges in 240.4 seconds so far...
#   Processed 12635 edges in 245.4 seconds so far...
#   Processed 12892 edges in 250.4 seconds so far...
#   Processed 13149 edges in 255.4 seconds so far...
#   Processed 13403 edges in 260.4 seconds so far...
#   Processed 13657 edges in 265.4 seconds so far...
#   Processed 13913 edges in 270.5 seconds so far...
#   Processed 14167 edges in 275.5 seconds so far...
#   Processed 14422 edges in 280.5 seconds so far...
#   Processed 14680 edges in 285.5 seconds so far...
#   Processed 14935 edges in 290.5 seconds so far...
#   Processed 15190 edges in 295.5 seconds so far...
#   Processed 15446 edges in 300.5 seconds so far...
#   Processed 15704 edges in 305.5 seconds so far...
#   Processed 15959 edges in 310.5 seconds so far...
#   Processed 16219 edges in 315.6 seconds so far...
#   Processed 16479 edges in 320.6 seconds so far...
#   Processed 16739 edges in 325.6 seconds so far...
#   Processed 17000 edges in 330.6 seconds so far...
#   Processed 17259 edges in 335.6 seconds so far...
#   Processed 17518 edges in 340.6 seconds so far...
#   Processed 17775 edges in 345.6 seconds so far...
#   Processed 51316 edges in 996.9 seconds so far...
#   Processed 51576 edges in 1001.9 seconds so far...
#   Processed 51835 edges in 1006.9 seconds so far...
#   Processed 52095 edges in 1011.9 seconds so far...
#   Processed 52356 edges in 1016.9 seconds so far...
#   Processed 52614 edges in 1021.9 seconds so far...
#   Processed 52873 edges in 1026.9 seconds so far...
#   Processed 53133 edges in 1031.9 seconds so far...
#   Processed 53392 edges in 1036.9 seconds so far...
#   Processed 53653 edges in 1042.0 seconds so far...
#   Processed 53912 edges in 1047.0 seconds so far...
#   Processed 54172 edges in 1052.0 seconds so far...
#   Processed 54433 edges in 1057.0 seconds so far...
#   Processed 54692 edges in 1062.0 seconds so far...
#   Processed 54953 edges in 1067.0 seconds so far...
#   Processed 55211 edges in 1072.1 seconds so far...
#   Processed 55470 edges in 1077.1 seconds so far...
#   Processed 55730 edges in 1082.1 seconds so far...
#   Processed 55987 edges in 1087.1 seconds so far...
#   Processed 56247 edges in 1092.1 seconds so far...
#   Processed 56507 edges in 1097.1 seconds so far...
#   Processed 56766 edges in 1102.1 seconds so far...
#   Processed 57026 edges in 1107.1 seconds so far...
#   Processed 57284 edges in 1112.1 seconds so far...
#   Processed 57543 edges in 1117.1 seconds so far...
#   Processed 57803 edges in 1122.2 seconds so far...
#   Processed 58063 edges in 1127.2 seconds so far...
#   Processed 58323 edges in 1132.2 seconds so far...
#   Processed 58581 edges in 1137.2 seconds so far...
#   Processed 58841 edges in 1142.2 seconds so far...
#   Processed 59101 edges in 1147.2 seconds so far...
#   Processed 59360 edges in 1152.2 seconds so far...
#   Processed 59620 edges in 1157.2 seconds so far...
#   Processed 59877 edges in 1162.2 seconds so far...
#   Processed 60137 edges in 1167.3 seconds so far...
#   Processed 60397 edges in 1172.3 seconds so far...
#   Processed 60657 edges in 1177.3 seconds so far...
#   Processed 60915 edges in 1182.3 seconds so far...
#   Processed 61171 edges in 1187.3 seconds so far...
#   Processed 61430 edges in 1192.3 seconds so far...
#   Processed 61686 edges in 1197.3 seconds so far...
#   Processed 61944 edges in 1202.3 seconds so far...
#   Processed 62202 edges in 1207.3 seconds so far...
#   Processed 62458 edges in 1212.4 seconds so far...
#   Processed 62717 edges in 1217.4 seconds so far...
#   Processed 62975 edges in 1222.4 seconds so far...
#   Processed 63234 edges in 1227.4 seconds so far...
#   Processed 63492 edges in 1232.4 seconds so far...
#   Processed 63751 edges in 1237.4 seconds so far...
#   Processed 64010 edges in 1242.4 seconds so far...
#   Processed 64266 edges in 1247.4 seconds so far...
#   Processed 64525 edges in 1252.4 seconds so far...
#   Processed 64783 edges in 1257.5 seconds so far...
#   Processed 65041 edges in 1262.5 seconds so far...
#   Processed 65299 edges in 1267.5 seconds so far...
#   Processed 65559 edges in 1272.5 seconds so far...
#   Processed 65818 edges in 1277.5 seconds so far...
#   Processed 66077 edges in 1282.5 seconds so far...
#   Processed 66336 edges in 1287.5 seconds so far...
#   Processed 66593 edges in 1292.5 seconds so far...
#   Processed 66853 edges in 1297.5 seconds so far...
#   Processed 67112 edges in 1302.5 seconds so far...
#   Processed 99550 edges in 1928.7 seconds so far...
#   Processed 99812 edges in 1933.7 seconds so far...
#   Processed 100074 edges in 1938.7 seconds so far...
#   Processed 100335 edges in 1943.7 seconds so far...
#   Processed 100595 edges in 1948.7 seconds so far...
#   Processed 100857 edges in 1953.8 seconds so far...
#   Processed 101119 edges in 1958.8 seconds so far...
#   Processed 101381 edges in 1963.8 seconds so far...
#   Processed 101640 edges in 1968.8 seconds so far...
#   Processed 101900 edges in 1973.8 seconds so far...
#   Processed 102160 edges in 1978.8 seconds so far...
#   Processed 102419 edges in 1983.8 seconds so far...
#   Processed 102678 edges in 1988.8 seconds so far...
#   Processed 102941 edges in 1993.9 seconds so far...
#   Processed 103201 edges in 1998.9 seconds so far...
#   Processed 103461 edges in 2003.9 seconds so far...
#   Processed 103722 edges in 2008.9 seconds so far...
#   Processed 103984 edges in 2013.9 seconds so far...
#   Processed 104244 edges in 2018.9 seconds so far...
#   Processed 104505 edges in 2023.9 seconds so far...
#   Processed 104765 edges in 2028.9 seconds so far...
#   Processed 105026 edges in 2033.9 seconds so far...
#   Processed 105288 edges in 2038.9 seconds so far...
#   Processed 105551 edges in 2044.0 seconds so far...
#   Processed 105810 edges in 2049.0 seconds so far...
#   Processed 106070 edges in 2054.0 seconds so far...
#   Processed 106328 edges in 2059.0 seconds so far...
#   Processed 106588 edges in 2064.0 seconds so far...
#   Processed 106848 edges in 2069.0 seconds so far...
#   Processed 107108 edges in 2074.0 seconds so far...
#   Processed 107366 edges in 2079.0 seconds so far...
#   Processed 107629 edges in 2084.0 seconds so far...
#   Processed 107888 edges in 2089.0 seconds so far...
#   Processed 108149 edges in 2094.0 seconds so far...
#   Processed 108410 edges in 2099.1 seconds so far...
#   Processed 108672 edges in 2104.1 seconds so far...
#   Processed 108933 edges in 2109.1 seconds so far...
#   Processed 109194 edges in 2114.1 seconds so far...
#   Processed 109454 edges in 2119.1 seconds so far...
#   Processed 109715 edges in 2124.1 seconds so far...
#   Processed 109975 edges in 2129.1 seconds so far...
#   Processed 110236 edges in 2134.1 seconds so far...
#   Processed 110497 edges in 2139.1 seconds so far...
#   Processed 110758 edges in 2144.2 seconds so far...
#   Processed 111019 edges in 2149.2 seconds so far...
#   Processed 111279 edges in 2154.2 seconds so far...
#   Processed 111541 edges in 2159.2 seconds so far...
#   Processed 111802 edges in 2164.2 seconds so far...
#   Processed 112064 edges in 2169.2 seconds so far...
#   Processed 112325 edges in 2174.2 seconds so far...
#   Processed 112586 edges in 2179.2 seconds so far...
#   Processed 112849 edges in 2184.2 seconds so far...
#   Processed 113111 edges in 2189.2 seconds so far...
#   Processed 113374 edges in 2194.3 seconds so far...
#   Processed 113636 edges in 2199.3 seconds so far...
#   Processed 113897 edges in 2204.3 seconds so far...
#   Processed 114160 edges in 2209.3 seconds so far...
#   Processed 114421 edges in 2214.3 seconds so far...
#   Processed 114683 edges in 2219.3 seconds so far...
#   Processed 114947 edges in 2224.3 seconds so far...
#   Processed 115210 edges in 2229.3 seconds so far...
#   Processed 115474 edges in 2234.4 seconds so far...
#   Processed 115732 edges in 2239.4 seconds so far...
#   Processed 115995 edges in 2244.4 seconds so far...
#   Processed 116258 edges in 2249.4 seconds so far...
#   Processed 116520 edges in 2254.4 seconds so far...
#   Processed 116782 edges in 2259.4 seconds so far...
#   Processed 117044 edges in 2264.4 seconds so far...
#   Processed 117307 edges in 2269.4 seconds so far...
#   Processed 117566 edges in 2274.4 seconds so far...
#   Processed 117825 edges in 2279.4 seconds so far...
#   Processed 118084 edges in 2284.4 seconds so far...
#   Processed 118343 edges in 2289.5 seconds so far...
#   Processed 118602 edges in 2294.5 seconds so far...
#   Processed 118860 edges in 2299.5 seconds so far...
#   Processed 119118 edges in 2304.5 seconds so far...
#   Processed 119379 edges in 2309.5 seconds so far...
#   Processed 119639 edges in 2314.5 seconds so far...
#   Processed 119902 edges in 2319.5 seconds so far...
#   Processed 120163 edges in 2324.5 seconds so far...
#   Processed 120425 edges in 2329.5 seconds so far...
#   Processed 120686 edges in 2334.5 seconds so far...
#   Processed 120949 edges in 2339.5 seconds so far...
#   Processed 121212 edges in 2344.5 seconds so far...
#   Processed 121474 edges in 2349.5 seconds so far...
#   Processed 121737 edges in 2354.5 seconds so far...
#   Processed 121999 edges in 2359.5 seconds so far...
#   Processed 122263 edges in 2364.5 seconds so far...
#   Processed 122523 edges in 2369.6 seconds so far...
#   Processed 122785 edges in 2374.6 seconds so far...
#   Processed 123047 edges in 2379.6 seconds so far...
#   Processed 123306 edges in 2384.6 seconds so far...
#   Processed 123570 edges in 2389.6 seconds so far...
#   Processed 123833 edges in 2394.6 seconds so far...
#   Processed 124095 edges in 2399.6 seconds so far...
#   Processed 124358 edges in 2404.6 seconds so far...
#   Processed 124620 edges in 2409.7 seconds so far...
#   Processed 124883 edges in 2414.7 seconds so far...
#   Processed 125145 edges in 2419.7 seconds so far...
#   Processed 125407 edges in 2424.7 seconds so far...
#   Processed 125670 edges in 2429.7 seconds so far...
#   Processed 125934 edges in 2434.7 seconds so far...
#   Processed 126196 edges in 2439.7 seconds so far...
#   Processed 126460 edges in 2444.7 seconds so far...
#   Processed 126723 edges in 2449.7 seconds so far...
#   Processed 126982 edges in 2454.7 seconds so far...
#   Processed 127243 edges in 2459.7 seconds so far...
#   Processed 127505 edges in 2464.8 seconds so far...
#   Processed 127767 edges in 2469.8 seconds so far...
#   Processed 128030 edges in 2474.8 seconds so far...
#   Processed 128292 edges in 2479.8 seconds so far...
#   Processed 128554 edges in 2484.8 seconds so far...
#   Processed 128815 edges in 2489.8 seconds so far...
#   Processed 129077 edges in 2494.8 seconds so far...
#   Processed 129340 edges in 2499.8 seconds so far...
#   Processed 129601 edges in 2504.8 seconds so far...
#   Processed 129864 edges in 2509.8 seconds so far...
#   Processed 130128 edges in 2514.9 seconds so far...
#   Processed 130390 edges in 2519.9 seconds so far...
#   Processed 130653 edges in 2524.9 seconds so far...
#   Processed 130917 edges in 2529.9 seconds so far...
#   Processed 131180 edges in 2534.9 seconds so far...
#   Processed 131442 edges in 2539.9 seconds so far...
#   Processed 131704 edges in 2544.9 seconds so far...
#   Processed 131966 edges in 2549.9 seconds so far...
#   Processed 132221 edges in 2554.9 seconds so far...
#   Processed 132482 edges in 2559.9 seconds so far...
#   Processed 132745 edges in 2564.9 seconds so far...
#   Processed 133008 edges in 2569.9 seconds so far...
#   Processed 133270 edges in 2574.9 seconds so far...
#   Processed 133534 edges in 2579.9 seconds so far...
#   Processed 133798 edges in 2584.9 seconds so far...
#   Processed 134063 edges in 2590.0 seconds so far...
#   Processed 134324 edges in 2595.0 seconds so far...
#   Processed 134588 edges in 2600.0 seconds so far...
#   Processed 134850 edges in 2605.0 seconds so far...
#   Processed 135114 edges in 2610.0 seconds so far...
#   Processed 135378 edges in 2615.0 seconds so far...
#   Processed 135643 edges in 2620.0 seconds so far...
#   Processed 135906 edges in 2625.0 seconds so far...
#   Processed 136170 edges in 2630.1 seconds so far...
#   Processed 136433 edges in 2635.1 seconds so far...
#   Processed 136697 edges in 2640.1 seconds so far...
#   Processed 136960 edges in 2645.1 seconds so far...
#   Processed 137222 edges in 2650.1 seconds so far...
#   Processed 137484 edges in 2655.1 seconds so far...
#   Processed 137747 edges in 2660.1 seconds so far...
#   Processed 138009 edges in 2665.1 seconds so far...
#   Processed 138273 edges in 2670.1 seconds so far...
#   Processed 138536 edges in 2675.1 seconds so far...
#   Processed 138799 edges in 2680.1 seconds so far...
#   Processed 139062 edges in 2685.1 seconds so far...
#   Processed 139326 edges in 2690.1 seconds so far...
#   Processed 139588 edges in 2695.2 seconds so far...
#   Processed 139852 edges in 2700.2 seconds so far...
#   Processed 140115 edges in 2705.2 seconds so far...
#   Processed 140379 edges in 2710.2 seconds so far...
#   Processed 140644 edges in 2715.2 seconds so far...
#   Processed 140906 edges in 2720.2 seconds so far...
#   Processed 141169 edges in 2725.2 seconds so far...
#   Processed 141432 edges in 2730.2 seconds so far...
#   Processed 141693 edges in 2735.2 seconds so far...
#   Processed 141957 edges in 2740.3 seconds so far...
#   Processed 142222 edges in 2745.3 seconds so far...
#   Processed 142487 edges in 2750.3 seconds so far...
#   Processed 142751 edges in 2755.3 seconds so far...
#   Processed 143014 edges in 2760.3 seconds so far...
#   Processed 143278 edges in 2765.3 seconds so far...
#   Processed 143543 edges in 2770.3 seconds so far...
#   Processed 143807 edges in 2775.3 seconds so far...
#   Processed 144072 edges in 2780.3 seconds so far...
#   Processed 144336 edges in 2785.3 seconds so far...
#   Processed 144600 edges in 2790.3 seconds so far...
#   Processed 144862 edges in 2795.4 seconds so far...
#   Processed 145127 edges in 2800.4 seconds so far...
#   Processed 145391 edges in 2805.4 seconds so far...
#   Processed 145654 edges in 2810.4 seconds so far...
#   Processed 145917 edges in 2815.4 seconds so far...
#   Processed 146181 edges in 2820.4 seconds so far...
#   Processed 146446 edges in 2825.4 seconds so far...
#   Processed 146711 edges in 2830.4 seconds so far...
#   Processed 146975 edges in 2835.4 seconds so far...
#   Processed 147239 edges in 2840.4 seconds so far...
#   Processed 147503 edges in 2845.4 seconds so far...
#   Processed 147764 edges in 2850.4 seconds so far...
#   Processed 148027 edges in 2855.4 seconds so far...
#   Processed 148292 edges in 2860.5 seconds so far...
#   Processed 148553 edges in 2865.5 seconds so far...
#   Processed 148815 edges in 2870.5 seconds so far...
#   Processed 149078 edges in 2875.5 seconds so far...
#   Processed 149341 edges in 2880.5 seconds so far...
#   Processed 149604 edges in 2885.5 seconds so far...
#   Processed 149869 edges in 2890.5 seconds so far...
#   Processed 150132 edges in 2895.5 seconds so far...
#   Processed 150395 edges in 2900.5 seconds so far...
#   Processed 150658 edges in 2905.5 seconds so far...
#   Processed 150923 edges in 2910.5 seconds so far...
#   Processed 151186 edges in 2915.6 seconds so far...
#   Processed 151450 edges in 2920.6 seconds so far...
#   Processed 151712 edges in 2925.6 seconds so far...
#   Processed 151975 edges in 2930.6 seconds so far...
#   Processed 152238 edges in 2935.6 seconds so far...
#   Processed 152502 edges in 2940.6 seconds so far...
#   Processed 152766 edges in 2945.6 seconds so far...
#   Processed 153030 edges in 2950.6 seconds so far...
#   Processed 153293 edges in 2955.7 seconds so far...
#   Processed 153555 edges in 2960.7 seconds so far...
#   Processed 153819 edges in 2965.7 seconds so far...
#   Processed 154083 edges in 2970.7 seconds so far...
#   Processed 154346 edges in 2975.7 seconds so far...
#   Processed 154610 edges in 2980.7 seconds so far...
#   Processed 154872 edges in 2985.7 seconds so far...
#   Processed 155134 edges in 2990.7 seconds so far...
#   Processed 155397 edges in 2995.7 seconds so far...
#   Processed 155662 edges in 3000.7 seconds so far...
#   Processed 155926 edges in 3005.7 seconds so far...
#   Processed 156190 edges in 3010.7 seconds so far...
#   Processed 156454 edges in 3015.7 seconds so far...
#   Processed 156717 edges in 3020.8 seconds so far...
#   Processed 156982 edges in 3025.8 seconds so far...
#   Processed 157249 edges in 3030.8 seconds so far...
#   Processed 157515 edges in 3035.8 seconds so far...
#   Processed 157781 edges in 3040.8 seconds so far...
#   Processed 158047 edges in 3045.8 seconds so far...
#   Processed 158313 edges in 3050.8 seconds so far...
#   Processed 158579 edges in 3055.9 seconds so far...
#   Processed 158844 edges in 3060.9 seconds so far...
#   Processed 159109 edges in 3065.9 seconds so far...
#   Processed 159376 edges in 3070.9 seconds so far...
#   Processed 159642 edges in 3075.9 seconds so far...
#   Processed 159907 edges in 3080.9 seconds so far...
#   Processed 160174 edges in 3085.9 seconds so far...
#   Processed 160442 edges in 3090.9 seconds so far...
#   Processed 160708 edges in 3095.9 seconds so far...
#   Processed 160974 edges in 3100.9 seconds so far...
#   Processed 161240 edges in 3105.9 seconds so far...
#   Processed 161505 edges in 3110.9 seconds so far...
#   Processed 161771 edges in 3115.9 seconds so far...
#   Processed 162037 edges in 3121.0 seconds so far...
#   Processed 162304 edges in 3126.0 seconds so far...
#   Processed 162570 edges in 3131.0 seconds so far...
#   Processed 162834 edges in 3136.0 seconds so far...
#   Processed 163100 edges in 3141.0 seconds so far...
#   Processed 163367 edges in 3146.0 seconds so far...
#   Processed 163633 edges in 3151.0 seconds so far...
#   Processed 163900 edges in 3156.0 seconds so far...
#   Processed 164167 edges in 3161.1 seconds so far...
#   Processed 164435 edges in 3166.1 seconds so far...
#   Processed 164701 edges in 3171.1 seconds so far...
#   Processed 164966 edges in 3176.1 seconds so far...
#   Processed 165234 edges in 3181.1 seconds so far...
#   Processed 165500 edges in 3186.1 seconds so far...
#   Processed 165766 edges in 3191.1 seconds so far...
#   Processed 166031 edges in 3196.1 seconds so far...
#   Processed 166298 edges in 3201.1 seconds so far...
#   Processed 166564 edges in 3206.1 seconds so far...
#   Processed 166831 edges in 3211.1 seconds so far...
#   Processed 167097 edges in 3216.1 seconds so far...
#   Processed 167365 edges in 3221.2 seconds so far...
#   Processed 167631 edges in 3226.2 seconds so far...
#   Processed 167899 edges in 3231.2 seconds so far...
#   Processed 168163 edges in 3236.2 seconds so far...
#   Processed 168428 edges in 3241.2 seconds so far...
#   Processed 168695 edges in 3246.2 seconds so far...
#   Processed 168962 edges in 3251.2 seconds so far...
#   Processed 169230 edges in 3256.3 seconds so far...
#   Processed 169495 edges in 3261.3 seconds so far...
#   Processed 169764 edges in 3266.3 seconds so far...
#   Processed 170030 edges in 3271.3 seconds so far...
#   Processed 170296 edges in 3276.3 seconds so far...
#   Processed 170565 edges in 3281.3 seconds so far...
#   Processed 170832 edges in 3286.3 seconds so far...

# %%
my_neo4j_nodes_relationships()
# Out:
# -------------------------
#   Nodes:
# -------------------------
#       node_name  labels  node_id
# 0          None  [Page]      107
# 1          None  [Page]      108
# 2          None  [Page]      109
# 3          None  [Page]      110
# 4          None  [Page]      111
# ...         ...     ...      ...
# 22465      None  [Page]    22171
# 22466      None  [Page]    22172
# 22467      None  [Page]    22173
# 22468      None  [Page]    22174
# 22469      None  [Page]    22175
#
# [22470 rows x 3 columns]
# -------------------------
#   Relationships:
# -------------------------
#         node_id_1 node_1_labels relationship_type  node_id_2 node_2_labels
# 0               0        [Page]             LIKES      18427        [Page]
# 1               1        [Page]             LIKES       2812        [Page]
# 2               1        [Page]             LIKES       4987        [Page]
# 3               1        [Page]             LIKES       5228        [Page]
# 4               1        [Page]             LIKES       5307        [Page]
# ...           ...           ...               ...        ...           ...
# 170997      22464        [Page]             LIKES      14438        [Page]
# 170998      22464        [Page]             LIKES      18876        [Page]
# 170999      22464        [Page]             LIKES      18892        [Page]
# 171000      22464        [Page]             LIKES      18927        [Page]
# 171001      22464        [Page]             LIKES      20810        [Page]
#
# [171002 rows x 5 columns]
# -------------------------

# %%
# Create a projection of the graph
query = '''

MATCH (a)-[r:LIKES]->(b)
WITH DISTINCT a, b, r

WITH gds.graph.project('connected-facebook-graph', 
    a,  
    b,  
    {
        sourceNodeLabels: labels(a),
        targetNodeLabels: labels(b),
        sourceNodeProperties: a { facebook_id: a.facebook_id}, 
        targetNodeProperties: b { facebook_id: b.facebook_id},
        relationshipType: type(r)
    }
)
as g
RETURN g.graphName AS graph, g.nodeCount AS nodes, g.relationshipCount AS rels
'''
df = my_neo4j_run_query_pandas(query)
df
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_190/3837910120.py in <module>
#      19 RETURN g.graphName AS graph, g.nodeCount AS nodes, g.relationshipCount AS rels
#      20 '''
# ---> 21 df = my_neo4j_run_query_pandas(query)
#      22 df
#
# /tmp/ipykernel_190/4174714270.py in my_neo4j_run_query_pandas(query, **kwargs)
#       2     "run a query and return the results in a pandas dataframe"
#       3     result = session.run(query, **kwargs)
# ----> 4     df = pd.DataFrame([r.values() for r in result], columns=result.keys())
#       5     return df
#
# /tmp/ipykernel_190/4174714270.py in <listcomp>(.0)
#       2     "run a query and return the results in a pandas dataframe"
#       3     result = session.run(query, **kwargs)
# ----> 4     df = pd.DataFrame([r.values() for r in result], columns=result.keys())
#       5     return df
#
# /opt/conda/lib/python3.9/site-packages/neo4j/_sync/work/result.py in __iter__(self)
#     376                 yield self._record_buffer.popleft()
#     377             elif self._streaming:
# --> 378                 self._connection.fetch_message()
#     379             elif self._discarding:
#     380                 self._discard()
#
# /opt/conda/lib/python3.9/site-packages/neo4j/_sync/io/_common.py in inner(*args, **kwargs)
#     176             def inner(*args, **kwargs):
#     177                 try:
# --> 178                     func(*args, **kwargs)
#     179                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180                     assert not asyncio.iscoroutinefunction(self.__on_error)
#
# /opt/conda/lib/python3.9/site-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     858             hydration_hooks=self.responses[0].hydration_hooks
#     859         )
# --> 860         res = self._process_message(tag, fields)
#     861         self.idle_since = monotonic()
#     862         return res
#
# /opt/conda/lib/python3.9/site-packages/neo4j/_sync/io/_bolt5.py in _process_message(self, tag, fields)
#     368             self._server_state_manager.state = self.bolt_states.FAILED
#     369             try:
# --> 370                 response.on_failure(summary_metadata or {})
#     371             except (ServiceUnavailable, DatabaseUnavailable):
#     372                 if self.pool:
#
# /opt/conda/lib/python3.9/site-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     243         handler = self.handlers.get("on_summary")
#     244         Util.callback(handler)
# --> 245         raise Neo4jError.hydrate(**metadata)
#     246
#     247     def on_ignored(self, metadata=None):
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke function `gds.graph.project`: Caused by: java.lang.IllegalArgumentException: Graph connected-facebook-graph already exists}

# %%
# PageRank implementation
query = """

CALL gds.pageRank.stream('connected-facebook-graph',
                         { maxIterations: $max_iterations,
                           dampingFactor: $damping_factor}
                         )
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).page_name AS name, score as page_rank
ORDER BY page_rank DESC, name ASC

"""

max_iterations = 20
damping_factor = 0.05

my_neo4j_run_query_pandas(query, max_iterations=max_iterations, damping_factor=damping_factor)
# Out:
#                            name  page_rank
# 0              Joachim Herrmann   4.323256
# 1         The Obama White House   3.983636
# 2        Sir Peter Bottomley MP   3.937708
# 3               The White House   2.969697
# 4      U.S. Army Chaplain Corps   2.898097
# ...                         ...        ...
# 22465                    식샤를합시다   0.950000
# 22466                      인사이트   0.950000
# 22467              컴투스 (Com2uS)   0.950000
# 22468                 한국안의 이스라엘   0.950000
# 22469                     현대자동차   0.950000
#
# [22470 rows x 2 columns]

# %%
#Shortest Path (Dijkstra's algorithm)
query = """

MATCH (source:Page {name: $source}), (target:Page {name: $target})
CALL gds.shortestPath.dijkstra.stream(
    'connected-facebook-graph', 
    { sourceNode: $source, 
      targetNode: $target, 
      relationshipWeightProperty: 'LIKES'
    }
)
YIELD index, sourceNode, targetNode, nodeIds, path
RETURN
    gds.util.asNode(sourceNode).name AS from,
    gds.util.asNode(targetNode).name AS to,
    [nodeId IN nodeIds | gds.util.asNode(nodeId).name] AS nodes
ORDER BY index


"""

source = "20892"
target = "127"

my_neo4j_run_query_pandas(query, source=source, target=target)

# %%
#Shortest Path (Dijkstra's algorithm)
query = """
MATCH (source:Page {id: $source}), (target:Page {id: $target})
CALL gds.shortestPath.dijkstra.stream(
    'connected-facebook-graph', 
    { sourceNode: $source, 
      targetNode:  $target})
YIELD index, sourceNode, targetNode, nodeIds, path
RETURN index, sourceNode, targetNode, nodeIds, path
ORDER BY index

"""

source= "20892"
target= "127"

my_neo4j_run_query_pandas(query, source=source, target=target)

# %%
# Community Detection
query = """
CALL gds.louvain.stream('connected-facebook-graph')
YIELD nodeId, communityId
RETURN gds.util.asNode(nodeId).id AS pageId, communityId
ORDER BY communityId, pageId
"""
my_neo4j_run_query_pandas(query)

# %%
# Add communityId to page
query = """
CALL gds.louvain.write('connected-facebook-graph', {
  writeProperty: 'communityId'
})
"""
my_neo4j_run_query_pandas(query)

# %%
# Create a Community node for each unique communityId
query = """
MATCH (p:Page)
WITH DISTINCT p.communityId AS communityId
MERGE (c:Community {communityId: communityId})
"""
my_neo4j_run_query_pandas(query)

# %%
# Create a Community node for each unique communityId
query = """
MATCH (a:Page)-[:LIKES]->(b:Page)
WHERE a.communityId <> b.communityId
WITH a.communityId AS source, b.communityId AS target, COUNT(*) AS interLinks

// Get community sizes
MATCH (c1:Community), (c2:Community)
WHERE c1.communityId = source AND c2.communityId = target
WITH c1, c2, interLinks,
     (c1.size + c2.size) AS combinedSize

MERGE (c1)-[r:INTER_COMMUNITY_LINK]->(c2)
SET r.weight = interLinks * combinedSize
"""
my_neo4j_run_query_pandas(query)

# %%
# Set size to the community nodes
query = """
MATCH (p:Page)
WITH p.communityId AS communityId, COUNT(*) AS size
MATCH (c:Community {communityId: communityId})
SET c.size = size
"""
my_neo4j_run_query_pandas(query)

# %%
# Community Detection
query = """
CALL gds.louvain.stream('connected-facebook-graph')
YIELD nodeId, communityId
WITH gds.util.asNode(nodeId) AS node, communityId
RETURN node.page_name AS page_name, communityId
ORDER BY communityId, page_name
"""
df = my_neo4j_run_query_pandas(query)

# Save to CSV
df.to_csv('community_detection_results.csv', index=False)
unique_communities = df["communityId"].nunique()
print(f"Number of unique communities: {unique_communities}")

# %%
# Load the CSV
df = pd.read_csv('community_detection_results.csv')

# Group by communityId and aggregate page names
grouped = df.groupby('communityId')['page_name'].apply(list).reset_index()

# Function to generate a community name (simple example: use most common word)
def summarize_names(page_names):
    from collections import Counter
    words = []
    for name in page_names:
        words.extend(name.split())
    most_common = Counter(words).most_common(3)
    return ' '.join([w for w, _ in most_common]) + ' Community'

grouped['community_name'] = grouped['page_name'].apply(summarize_names)

# Select the community columns
result = grouped[['communityId', 'community_name']]

# Save to CSV
result.to_csv('community_names_full.csv', index=False)

# %%
# Update community with basic community name
import time
import pandas as pd

community_df = pd.read_csv('community_names_full.csv')
start_time = time.time()
last_print_time = start_time

for i, row in community_df.iterrows():
    community_id = int(row["communityId"])
    community_name = row["community_name"]

    query = """
    MATCH (c:Community {communityId: $community_id})
    SET c.communityName = $community_name
    """
    session.run(query, {"community_id": community_id, "community_name": community_name})

    # Print progress every 5 seconds
    current_time = time.time()
    if current_time - last_print_time > 5:
        elapsed = current_time - start_time
        print(f"  Processed {i} community labels in {elapsed:.1f} seconds so far...")
        last_print_time = current_time

print("Done")

# %%
# Aggregate pages per community 
query = """
MATCH (c:Community)
WITH c
MATCH (p:Page)
WHERE p.communityId = c.communityId
WITH c, collect(p.page_name) AS pageNames
SET c.pages = pageNames
"""
my_neo4j_run_query_pandas(query)

# %%
# Community Detection -- Run this command in browser
query = """
MATCH (c1:Community)-[r:INTER_COMMUNITY_LINK]->(c2:Community)
WHERE c1.communityName IS NOT NULL AND c2.communityName IS NOT NULL
RETURN c1, r, c2
LIMIT 1000
"""
my_neo4j_run_query_pandas(query)

# %%
#Shortest Path (Dijkstra's algorithm)
query = """

MATCH (source:Page) 
WHERE id(source) = $source
MATCH (target:Page) 
WHERE id(target) = $target
WITH id(source) AS sourceId, id(target) AS targetId
CALL gds.shortestPath.dijkstra.stream(
  'connected-facebook-graph',
  {
    sourceNode: sourceId,
    targetNode: targetId
  }
)
YIELD index, sourceNode, targetNode, nodeIds, path
RETURN
  index,
  gds.util.asNode(sourceNode).id AS fromId,
  gds.util.asNode(targetNode).id AS toId,
  [nodeId IN nodeIds | gds.util.asNode(nodeId).id] AS pathNodes
ORDER BY index

"""

source=	7
target=294

my_neo4j_run_query_pandas(query, source=source, target=target)

# %%
#Source node 1160 for Air Canada & Canadian Embassy
query = """

MATCH (source:Page) 
WHERE id(source) = $source
MATCH (target:Page) 
WHERE id(target) = $target
WITH id(source) AS sourceId, id(target) AS targetId
CALL gds.shortestPath.dijkstra.stream(
  'connected-facebook-graph',
  {
    sourceNode: sourceId,
    targetNode: targetId
  }
)
YIELD index, sourceNode, targetNode, nodeIds, path
RETURN
  index,
  gds.util.asNode(sourceNode).id AS fromId,
  gds.util.asNode(targetNode).id AS toId,
  [nodeId IN nodeIds | gds.util.asNode(nodeId).id] AS pathNodes  
ORDER BY index

"""
source_id=1160
target_id=21006

my_neo4j_run_query_pandas(query, source=source_id, target=target_id)
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 7, offset: 29} for query: "\n\nMATCH (source:Page) \nWHERE id(source) = $source\nMATCH (target:Page) \nWHERE id(target) = $target\nWITH id(source) AS sourceId, id(target) AS targetId\nCALL gds.shortestPath.dijkstra.stream(\n  'connected-facebook-graph',\n  {\n    sourceNode: sourceId,\n    targetNode: targetId\n  }\n)\nYIELD index, sourceNode, targetNode, nodeIds, path\nRETURN\n  index,\n  gds.util.asNode(sourceNode).id AS fromId,\n  gds.util.asNode(targetNode).id AS toId,\n  [nodeId IN nodeIds | gds.util.asNode(nodeId).id] AS pathNodes  \nORDER BY index\n\n"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 6, offset: 103} for query: "\n\nMATCH (source:Page) \nWHERE id(source) = $source\nMATCH (target:Page) \nWHERE id(target) = $target\nWITH id(source) AS sourceId, id(target) AS targetId\nCALL gds.shortestPath.dijkstra.stream(\n  'connected-facebook-graph',\n  {\n    sourceNode: sourceId,\n    targetNode: targetId\n  }\n)\nYIELD index, sourceNode, targetNode, nodeIds, path\nRETURN\n  index,\n  gds.util.asNode(sourceNode).id AS fromId,\n  gds.util.asNode(targetNode).id AS toId,\n  [nodeId IN nodeIds | gds.util.asNode(nodeId).id] AS pathNodes  \nORDER BY index\n\n"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 30, offset: 127} for query: "\n\nMATCH (source:Page) \nWHERE id(source) = $source\nMATCH (target:Page) \nWHERE id(target) = $target\nWITH id(source) AS sourceId, id(target) AS targetId\nCALL gds.shortestPath.dijkstra.stream(\n  'connected-facebook-graph',\n  {\n    sourceNode: sourceId,\n    targetNode: targetId\n  }\n)\nYIELD index, sourceNode, targetNode, nodeIds, path\nRETURN\n  index,\n  gds.util.asNode(sourceNode).id AS fromId,\n  gds.util.asNode(targetNode).id AS toId,\n  [nodeId IN nodeIds | gds.util.asNode(nodeId).id] AS pathNodes  \nORDER BY index\n\n"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 6, column: 7, offset: 77} for query: "\n\nMATCH (source:Page) \nWHERE id(source) = $source\nMATCH (target:Page) \nWHERE id(target) = $target\nWITH id(source) AS sourceId, id(target) AS targetId\nCALL gds.shortestPath.dijkstra.stream(\n  'connected-facebook-graph',\n  {\n    sourceNode: sourceId,\n    targetNode: targetId\n  }\n)\nYIELD index, sourceNode, targetNode, nodeIds, path\nRETURN\n  index,\n  gds.util.asNode(sourceNode).id AS fromId,\n  gds.util.asNode(targetNode).id AS toId,\n  [nodeId IN nodeIds | gds.util.asNode(nodeId).id] AS pathNodes  \nORDER BY index\n\n"
# Empty DataFrame
# Columns: [index, fromId, toId, pathNodes]
# Index: []

# %%
#Shortest Path (Dijkstra's algorithm) Air Canada to General Consulate of Switzerland
query = """

MATCH (source:Page {id: 1244}), (target:Page {id: 11319})
WITH id(source) AS sourceNodeId, id(target) AS targetNodeId

CALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {
  sourceNode: sourceNodeId,
  targetNode: targetNodeId
})
YIELD nodeIds
WITH [nodeId IN nodeIds | gds.util.asNode(nodeId).page_name] AS pageNames
RETURN pageNames"""


source_id=1244
target_id= 11319



my_neo4j_run_query_pandas(query, source=source_id, target=target_id)
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 34, offset: 93} for query: "\n\nMATCH (source:Page {id: 1244}), (target:Page {id: 11319})\nWITH id(source) AS sourceNodeId, id(target) AS targetNodeId\n\nCALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {\n  sourceNode: sourceNodeId,\n  targetNode: targetNodeId\n})\nYIELD nodeIds\nWITH [nodeId IN nodeIds | gds.util.asNode(nodeId).page_name] AS pageNames\nRETURN pageNames"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 6, offset: 65} for query: "\n\nMATCH (source:Page {id: 1244}), (target:Page {id: 11319})\nWITH id(source) AS sourceNodeId, id(target) AS targetNodeId\n\nCALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {\n  sourceNode: sourceNodeId,\n  targetNode: targetNodeId\n})\nYIELD nodeIds\nWITH [nodeId IN nodeIds | gds.util.asNode(nodeId).page_name] AS pageNames\nRETURN pageNames"
# Empty DataFrame
# Columns: [pageNames]
# Index: []

# %%
#Shortest Path (Dijkstra's algorithm) Air Canada to General Consulate of Switzerland
query = """
MATCH (source:Page {id: 1244}), (target:Page {id: 11319})
WITH id(source) AS sourceNodeId, id(target) AS targetNodeId

CALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {
  sourceNode: sourceNodeId,
  targetNode: targetNodeId
})
YIELD nodeIds
WITH nodeIds
UNWIND range(0, size(nodeIds)-2) AS i
MATCH (n1) WHERE id(n1) = nodeIds[i]
MATCH (n2) WHERE id(n2) = nodeIds[i + 1]
MATCH (n1)-[r:LIKES]-(n2)
RETURN n1, r, n2

"""


source_id=1244
target_id= 11319



my_neo4j_run_query_pandas(query, source=source_id, target=target_id)
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 3, column: 34, offset: 92} for query: "\nMATCH (source:Page {id: 1244}), (target:Page {id: 11319})\nWITH id(source) AS sourceNodeId, id(target) AS targetNodeId\n\nCALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {\n  sourceNode: sourceNodeId,\n  targetNode: targetNodeId\n})\nYIELD nodeIds\nWITH nodeIds\nUNWIND range(0, size(nodeIds)-2) AS i\nMATCH (n1) WHERE id(n1) = nodeIds[i]\nMATCH (n2) WHERE id(n2) = nodeIds[i + 1]\nMATCH (n1)-[r:LIKES]-(n2)\nRETURN n1, r, n2\n\n"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 12, column: 18, offset: 328} for query: "\nMATCH (source:Page {id: 1244}), (target:Page {id: 11319})\nWITH id(source) AS sourceNodeId, id(target) AS targetNodeId\n\nCALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {\n  sourceNode: sourceNodeId,\n  targetNode: targetNodeId\n})\nYIELD nodeIds\nWITH nodeIds\nUNWIND range(0, size(nodeIds)-2) AS i\nMATCH (n1) WHERE id(n1) = nodeIds[i]\nMATCH (n2) WHERE id(n2) = nodeIds[i + 1]\nMATCH (n1)-[r:LIKES]-(n2)\nRETURN n1, r, n2\n\n"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 3, column: 6, offset: 64} for query: "\nMATCH (source:Page {id: 1244}), (target:Page {id: 11319})\nWITH id(source) AS sourceNodeId, id(target) AS targetNodeId\n\nCALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {\n  sourceNode: sourceNodeId,\n  targetNode: targetNodeId\n})\nYIELD nodeIds\nWITH nodeIds\nUNWIND range(0, size(nodeIds)-2) AS i\nMATCH (n1) WHERE id(n1) = nodeIds[i]\nMATCH (n2) WHERE id(n2) = nodeIds[i + 1]\nMATCH (n1)-[r:LIKES]-(n2)\nRETURN n1, r, n2\n\n"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 13, column: 18, offset: 365} for query: "\nMATCH (source:Page {id: 1244}), (target:Page {id: 11319})\nWITH id(source) AS sourceNodeId, id(target) AS targetNodeId\n\nCALL gds.shortestPath.dijkstra.stream('connected-facebook-graph', {\n  sourceNode: sourceNodeId,\n  targetNode: targetNodeId\n})\nYIELD nodeIds\nWITH nodeIds\nUNWIND range(0, size(nodeIds)-2) AS i\nMATCH (n1) WHERE id(n1) = nodeIds[i]\nMATCH (n2) WHERE id(n2) = nodeIds[i + 1]\nMATCH (n1)-[r:LIKES]-(n2)\nRETURN n1, r, n2\n\n"
# Empty DataFrame
# Columns: [n1, r, n2]
# Index: []
